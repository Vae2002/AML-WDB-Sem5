# %%
# Notwendige Bibliotheken importieren
import pandas as pd
import requests
import random

# %% [markdown]
# ## Laden des Datensatzes
#
# Jetzt laden wir unseren Datensatz. Wir gehen davon aus, dass der Datensatz eine CSV-Datei mit Verkaufsdaten enthält.

# %% [markdown]
# Fetch Public and public Parking Data from the APIs

# %%
# API URL for Freiburg
api_url_freiburg = "https://api.parkendd.de/Freiburg"

# Fetch the data from the WFS API
response_freiburg = requests.get(api_url_freiburg)

# Check the response and parse the JSON data
if response_freiburg.status_code == 200:
    public_parking_data = response_freiburg.json()
    
    # Extract relevant data (you can modify based on the actual response structure)
    parking_data_public = []
    for site in public_parking_data['lots']:
        coords = site.get("coords", {})
        parking_data_public.append({
            "public_id": site.get("id"),
            "name": site.get("name"),
            "address": site.get("address"),
            "latitude": coords.get("lat"),  
            "longitude": coords.get("lng"),
            "price": 0,
            "capacity": site.get("total"),
            "available_space": site.get("free")
        })
    
    # Convert to DataFrame
    df_freiburg = pd.DataFrame(parking_data_public)
    print("public Parking Data:", df_freiburg.head())
else:
    print("Failed to fetch MobiData BW parking data.")
# Out:
# public Parking Data:                    public_id              name address   latitude  longitude  \
# 0         freiburgmartinstor        Martinstor     P18  47.992506   7.847365
# 1        freiburgunterlinden       Unterlinden      P8  47.997868   7.848868
# 2          freiburgvolksbank         Volksbank      P3  47.998021   7.843413
# 3    freiburgschwarzwaldcity  Schwarzwald City      P9  47.997206   7.851119
# 4  freiburgkollegiengebaeude  Kollegiengebäude     P19  47.993431   7.847403
#
#    price  capacity  available_space
# 0      0       132              132
# 1      0       218              204
# 2      0       186              117
# 3      0       416                0
# 4      0       153              145

# %%
# URL for MobiData BW API (public parking data)
api_url_gebündelte_parkplätze_parkbauten = "https://api.mobidata-bw.de/park-api/api/public/v3/parking-sites"

# Fetch data from MobiData BW API
response_gebündelte_parkplätze_parkbauten = requests.get(api_url_gebündelte_parkplätze_parkbauten)

# Check the response and parse the JSON data
if response_gebündelte_parkplätze_parkbauten.status_code == 200:
    public_parking_data = response_gebündelte_parkplätze_parkbauten.json()
    
    # Extract relevant data (you can modify based on the actual response structure)
    parking_data_public = []
    for site in public_parking_data['items']:
        parking_data_public.append({
            "public_id": site.get("id"),
            "name": site.get("name"),
            "address": site.get("address"),
            "latitude": site.get("lat"),  
            "longitude": site.get("lon"),
            "price": 0,
            "capacity": site.get("capacity"),
            "available_space": site.get("realtime_free_capacity")
        })
    
    # Convert to DataFrame
    df_public_parking = pd.DataFrame(parking_data_public)
    print("Public Parking Data:", df_public_parking.head())
else:
    print("Failed to fetch MobiData BW parking data.")
# Out:
# Public Parking Data:    public_id                                          name  \
# 0        887                   Listplatz 1 / Bahnhofstraße
# 1        888                           Obere Wässere 3 - 7
# 2       7150                   Berlin, Das Schloss Ebene A
# 3        437  Parkgarage Universität Kollegiengebäude (KG)
# 4      11291                                     Parkplatz
#
#                                              address    latitude   longitude  \
# 0            Listplatz 1 / Bahnhofstraße, Reutlingen  48.4959833   9.2103309
# 1                    Obere Wässere 3 - 7, Reutlingen  48.4889546   9.2167006
# 2                      Grunewaldstr. 3, 12163 Berlin  52.4572160  13.3201610
# 3  Zufahrt Humboldtstraße über Rempartstraße, 790...  47.9931202   7.8476608
# 4                                          Stuttgart  48.8059851   9.2350406
#
#    price  capacity  available_space
# 0      0     198.0              NaN
# 1      0     181.0              NaN
# 2      0     250.0              NaN
# 3      0     245.0            145.0
# 4      0      12.0              NaN

# %%
df_freiburg
# Out:
#                     public_id                name address   latitude  \
# 0          freiburgmartinstor          Martinstor     P18  47.992506
# 1         freiburgunterlinden         Unterlinden      P8  47.997868
# 2           freiburgvolksbank           Volksbank      P3  47.998021
# 3     freiburgschwarzwaldcity    Schwarzwald City      P9  47.997206
# 4   freiburgkollegiengebaeude    Kollegiengebäude     P19  47.993431
# 5   freiburgzentrumoberwiehre  Zentrum Oberwiehre     P21  47.987991
# 6         freiburgkonzerthaus         Konzerthaus      P2  47.995290
# 7      freiburgbahnhofsgarage      Bahnhofsgarage      P1  47.996932
# 8         freiburglandratsamt         Landratsamt     P14  48.000059
# 9          freiburgggrafhalle       G.-Graf-Halle      P6  47.999300
# 10   freiburgzurunterfuehrung    Zur Unterführung      P5  48.001286
# 11        freiburgschwabentor         Schwabentor     P16  47.991264
# 12          freiburgambahnhof          Am Bahnhof      P4  47.998971
# 13      freiburgzaehringertor       Zähringer Tor     P12  47.998958
# 14        freiburgwestarkaden         Westarkaden     P22  48.006420
# 15        freiburgschlossberg         Schlossberg     P15  47.994017
# 16     freiburgpaedhochschule     Päd. Hochschule     P20  47.982361
# 17            freiburgrotteck             Rotteck     P10  47.995801
# 18           freiburgkarlsbau            Karlsbau     P13  47.997446
#
#     longitude  price  capacity  available_space
# 0    7.847365      0       132              132
# 1    7.848868      0       218              204
# 2    7.843413      0       186              117
# 3    7.851119      0       416                0
# 4    7.847403      0       153              145
# 5    7.871473      0       274              241
# 6    7.840836      0       421              397
# 7    7.841420      0         0                0
# 8    7.857081      0       202              193
# 9    7.846800      0        56               53
# 10   7.844732      0       100               73
# 11   7.856310      0       193              150
# 12   7.842917      0       177              148
# 13   7.854022      0       162              102
# 14   7.827394      0       750              526
# 15   7.855142      0       430              400
# 16   7.890891      0       168               36
# 17   7.846298      0       300              283
# 18   7.853848      0       977              872

# %%
df_public_parking
# Out:
#       public_id                                          name  \
# 0           887                   Listplatz 1 / Bahnhofstraße
# 1           888                           Obere Wässere 3 - 7
# 2          7150                   Berlin, Das Schloss Ebene A
# 3           437  Parkgarage Universität Kollegiengebäude (KG)
# 4         11291                                     Parkplatz
# ...         ...                                           ...
# 8879      19853              Stansstad (zb - Die Zentralbahn)
# 8880       9239                                        Neyruz
# 8881      10058                                  Schliessfach
# 8882      19840                                      Gümligen
# 8883       9301                                        Sursee
#
#                                                 address    latitude  \
# 0               Listplatz 1 / Bahnhofstraße, Reutlingen  48.4959833
# 1                       Obere Wässere 3 - 7, Reutlingen  48.4889546
# 2                         Grunewaldstr. 3, 12163 Berlin  52.4572160
# 3     Zufahrt Humboldtstraße über Rempartstraße, 790...  47.9931202
# 4                                             Stuttgart  48.8059851
# ...                                                 ...         ...
# 8879                     Bahnhofstrasse, 6362 Stansstad  46.9771300
# 8880                   Chemin de la Gare 3, 1740 Neyruz  46.7664688
# 8881                                               None  49.1428451
# 8882                   Bahnhofstrasse 21, 3073 Gümligen  46.9334159
# 8883                       Bahnhofplatz 26, 6210 Sursee  47.1689620
#
#        longitude  price  capacity  available_space
# 0      9.2103309      0     198.0              NaN
# 1      9.2167006      0     181.0              NaN
# 2     13.3201610      0     250.0              NaN
# 3      7.8476608      0     245.0            145.0
# 4      9.2350406      0      12.0              NaN
# ...          ...    ...       ...              ...
# 8879   8.3360490      0      22.0              NaN
# 8880   7.0652059      0      11.0              NaN
# 8881   9.2137118      0      46.0              NaN
# 8882   7.5072258      0      23.0              NaN
# 8883   8.0999364      0      47.0              NaN
#
# [8884 rows x 8 columns]

# %% [markdown]
# Data Cleaning

# %%
# # Clean the Freiburg parking data
df_freiburg_cleaned = df_freiburg.dropna(subset=["public_id", "name", "address", "latitude", "longitude", "price", "capacity", "available_space"])  
df_freiburg_cleaned["available_space"] = df_freiburg_cleaned["available_space"].astype(int)

# Clean the public parking data
df_public_parking_cleaned = df_public_parking.dropna(subset=["public_id", "name", "address", "latitude", "longitude", "price", "capacity"]) 

# Remove duplicates based on parking ID
df_freiburg_cleaned = df_freiburg_cleaned.drop_duplicates(subset=["public_id"])
df_public_parking_cleaned = df_public_parking_cleaned.drop_duplicates(subset=["public_id"])

df_public_parking_cleaned
# Out:
#       public_id                                          name  \
# 0           887                   Listplatz 1 / Bahnhofstraße
# 1           888                           Obere Wässere 3 - 7
# 2          7150                   Berlin, Das Schloss Ebene A
# 3           437  Parkgarage Universität Kollegiengebäude (KG)
# 4         11291                                     Parkplatz
# ...         ...                                           ...
# 8878      19842                                         Frick
# 8879      19853              Stansstad (zb - Die Zentralbahn)
# 8880       9239                                        Neyruz
# 8882      19840                                      Gümligen
# 8883       9301                                        Sursee
#
#                                                 address    latitude  \
# 0               Listplatz 1 / Bahnhofstraße, Reutlingen  48.4959833
# 1                       Obere Wässere 3 - 7, Reutlingen  48.4889546
# 2                         Grunewaldstr. 3, 12163 Berlin  52.4572160
# 3     Zufahrt Humboldtstraße über Rempartstraße, 790...  47.9931202
# 4                                             Stuttgart  48.8059851
# ...                                                 ...         ...
# 8878                         Bahnhofplatz 1, 5070 Frick  47.5079729
# 8879                     Bahnhofstrasse, 6362 Stansstad  46.9771300
# 8880                   Chemin de la Gare 3, 1740 Neyruz  46.7664688
# 8882                   Bahnhofstrasse 21, 3073 Gümligen  46.9334159
# 8883                       Bahnhofplatz 26, 6210 Sursee  47.1689620
#
#        longitude  price  capacity  available_space
# 0      9.2103309      0     198.0              NaN
# 1      9.2167006      0     181.0              NaN
# 2     13.3201610      0     250.0              NaN
# 3      7.8476608      0     245.0            145.0
# 4      9.2350406      0      12.0              NaN
# ...          ...    ...       ...              ...
# 8878   8.0137422      0     139.0              NaN
# 8879   8.3360490      0      22.0              NaN
# 8880   7.0652059      0      11.0              NaN
# 8882   7.5072258      0      23.0              NaN
# 8883   8.0999364      0      47.0              NaN
#
# [6337 rows x 8 columns]

# %% [markdown]
# Data Integration

# %%
# Ensure latitude and longitude columns are numeric and consistent
df_freiburg_cleaned["latitude"] = pd.to_numeric(df_freiburg_cleaned["latitude"], errors="coerce")
df_freiburg_cleaned["longitude"] = pd.to_numeric(df_freiburg_cleaned["longitude"], errors="coerce")

df_public_parking_cleaned["latitude"] = pd.to_numeric(df_public_parking_cleaned["latitude"], errors="coerce")
df_public_parking_cleaned["longitude"] = pd.to_numeric(df_public_parking_cleaned["longitude"], errors="coerce")

# Drop rows with NaN in latitude or longitude
df_freiburg_cleaned = df_freiburg_cleaned.dropna(subset=["latitude", "longitude"])
df_public_parking_cleaned = df_public_parking_cleaned.dropna(subset=["latitude", "longitude"])

# Round latitude and longitude to the same precision for matching
df_freiburg_cleaned["latitude"] = df_freiburg_cleaned["latitude"].round(6)
df_freiburg_cleaned["longitude"] = df_freiburg_cleaned["longitude"].round(6)

df_public_parking_cleaned["latitude"] = df_public_parking_cleaned["latitude"].round(6)
df_public_parking_cleaned["longitude"] = df_public_parking_cleaned["longitude"].round(6)

# Merge the DataFrames, prioritizing df_public_parking_cleaned data
df_combined = pd.merge(
    df_freiburg_cleaned,
    df_public_parking_cleaned,
    on=["latitude", "longitude"],
    how="outer",
    suffixes=("_freiburg", "_public")
)

# Prioritize data from df_public_parking_cleaned
for column in df_public_parking_cleaned.columns:
    if column not in ["latitude", "longitude"]:  # Exclude keys used for merging
        df_combined[column] = df_combined[column + "_public"].combine_first(df_combined[column + "_freiburg"])

# Drop redundant columns
columns_to_drop = [col for col in df_combined.columns if col.endswith("_freiburg") or col.endswith("_public")]
df_combined = df_combined.drop(columns=columns_to_drop)

df_combined
# Out:
#        latitude  longitude public_id                           name  \
# 0     45.834007   9.027392   19828.0                        Chiasso
# 1     45.850126   8.944807    9316.0                         Stabio
# 2     45.870814   8.980929   19803.0                      Mendrisio
# 3     45.902308   8.978494    9332.0        Capolago-Riva S. Vitale
# 4     45.933311   8.972506    9340.0                Maroggia-Melano
# ...         ...        ...       ...                            ...
# 6336  54.177340  12.090144     363.0    Vorplatz Bahnhof Warnemünde
# 6337  54.309057  13.077329     339.0         Vorfahrt Stralsund Hbf
# 6338  54.472588   9.053282     237.0        Parkplatz Bahnhof Husum
# 6339  54.786282   9.436861    7182.0  Flensburg, City Süderhofenden
# 6340  58.343170   8.591238   19698.0                     Storgt. 38
#
#                                           address  price  capacity  \
# 0                      Via Livio 22, 6830 Chiasso    0.0     186.0
# 1                  Via Cantonaccio 3, 6855 Stabio    0.0      58.0
# 2     Via Stefano Franscini 20-28, 6850 Mendrisio    0.0     157.0
# 3      Via Segoma 2, 6825 Capolago-Riva S. Vitale    0.0      35.0
# 4          Viale Stazione 1, 6818 Maroggia-Melano    0.0      53.0
# ...                                           ...    ...       ...
# 6336                 Am Bahnhof, 18119 Warnemünde    0.0      11.0
# 6337               Tribseer Damm, 18437 Stralsund    0.0      11.0
# 6338                Poggenburgstraße, 25813 Husum    0.0      42.0
# 6339           Süderhofenden 4-6, 24937 Flensburg    0.0     490.0
# 6340                   Storgata 38, 4876 Grimstad    0.0      18.0
#
#       available_space
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 6336              NaN
# 6337              NaN
# 6338              NaN
# 6339              NaN
# 6340              NaN
#
# [6341 rows x 8 columns]

# %%
# Define desired column order
desired_columns = [
    "public_id", "name", "address", "latitude", "longitude", "price", "capacity", "available_space", "history_id"
]

# Reorder the columns in the combined DataFrame
df_combined = df_combined[[col for col in desired_columns if col in df_combined.columns]]

df_combined['public_id'] = df_combined['public_id'].apply(lambda x: f"PUB{random.randint(10000, 99999)}")

df_combined
# Out:
#      public_id                           name  \
# 0     PUB31128                        Chiasso
# 1     PUB63546                         Stabio
# 2     PUB86995                      Mendrisio
# 3     PUB17442        Capolago-Riva S. Vitale
# 4     PUB62624                Maroggia-Melano
# ...        ...                            ...
# 6336  PUB18740    Vorplatz Bahnhof Warnemünde
# 6337  PUB32706         Vorfahrt Stralsund Hbf
# 6338  PUB44162        Parkplatz Bahnhof Husum
# 6339  PUB18233  Flensburg, City Süderhofenden
# 6340  PUB79830                     Storgt. 38
#
#                                           address   latitude  longitude  \
# 0                      Via Livio 22, 6830 Chiasso  45.834007   9.027392
# 1                  Via Cantonaccio 3, 6855 Stabio  45.850126   8.944807
# 2     Via Stefano Franscini 20-28, 6850 Mendrisio  45.870814   8.980929
# 3      Via Segoma 2, 6825 Capolago-Riva S. Vitale  45.902308   8.978494
# 4          Viale Stazione 1, 6818 Maroggia-Melano  45.933311   8.972506
# ...                                           ...        ...        ...
# 6336                 Am Bahnhof, 18119 Warnemünde  54.177340  12.090144
# 6337               Tribseer Damm, 18437 Stralsund  54.309057  13.077329
# 6338                Poggenburgstraße, 25813 Husum  54.472588   9.053282
# 6339           Süderhofenden 4-6, 24937 Flensburg  54.786282   9.436861
# 6340                   Storgata 38, 4876 Grimstad  58.343170   8.591238
#
#       price  capacity  available_space
# 0       0.0     186.0              NaN
# 1       0.0      58.0              NaN
# 2       0.0     157.0              NaN
# 3       0.0      35.0              NaN
# 4       0.0      53.0              NaN
# ...     ...       ...              ...
# 6336    0.0      11.0              NaN
# 6337    0.0      11.0              NaN
# 6338    0.0      42.0              NaN
# 6339    0.0     490.0              NaN
# 6340    0.0      18.0              NaN
#
# [6341 rows x 8 columns]
