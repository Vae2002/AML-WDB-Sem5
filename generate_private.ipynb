# %%
# import random
# import json
# import datetime

# # Load the JSON data (assuming you have the file path)
# with open('landlord_data.json', 'r') as file:
#     landlord_data = json.load(file)

# def generate_landlord_id():
#     # Randomly select a landlord_id from the JSON data
#     return random.choice(landlord_data)['landlord_id']

# def generate_random_address():
#     # Streets and locations from various cities in Baden-Württemberg
#     streets = [
#         "Hauptstraße", "Schlossstraße", "Marktplatz", "Bahnhofstraße", "Karlsruher Straße",
#         "Ludwigsburger Straße", "Heidelberger Straße", "Stuttgarter Straße", "Bodenseestraße",
#         "Tübinger Straße", "Ulmer Straße", "Hegelstraße", "Goethestraße", "Mozartstraße",
#         "Kantstraße", "Friedrichstraße", "Wilhelmstraße"
#     ]
#     house_numbers = range(1, 150)

#     # List of cities in Baden-Württemberg and their coordinates (lat, lon)
#     cities_with_coords = {
#         "Stuttgart": (48.7758, 9.1829),
#         "Karlsruhe": (49.0144, 8.4044),
#         "Mannheim": (49.4875, 8.4647),
#         "Freiburg": (47.9990, 7.8425),
#         "Heidelberg": (49.3984, 8.6724),
#         "Ulm": (48.4011, 9.9876),
#         "Pforzheim": (48.8984, 8.7010),
#         "Reutlingen": (48.4815, 9.2043),
#         "Tübingen": (48.5204, 9.0568),
#         "Ludwigsburg": (48.8982, 9.1941),
#         "Esslingen": (48.7400, 9.3100),
#         "Baden-Baden": (48.7591, 8.2400),
#         "Konstanz": (47.6660, 9.1732),
#         "Villingen-Schwenningen": (48.0732, 8.4920)
#     }
    
#     street = random.choice(streets)
#     number = random.choice(house_numbers)

#     # Randomly select a city and its coordinates
#     city = random.choice(list(cities_with_coords.keys()))
#     coordinates = cities_with_coords[city]
    
#     return f"{street} {number}, {city}", coordinates

# def generate_opening_time():
#     start_date = datetime.datetime(2025, 1, 1)
#     end_date = datetime.datetime(2025, 12, 31)
#     delta = end_date - start_date

#     # Random start and end dates within the year
#     random_days = random.randint(0, delta.days)
#     random_start_date = start_date + datetime.timedelta(days=random_days)
#     random_end_date = random_start_date + datetime.timedelta(days=random.randint(1, 30))

#     # Generate random opening and closing times between 6 AM and 10 PM
#     opening_hour = random.randint(6, 21)  # Earliest opening time is 6 AM, latest is 9 PM
#     closing_hour = random.randint(opening_hour + 1, 22)  # Must close at least 1 hour later, latest is 10 PM

#     time_range = f"{opening_hour}AM-{closing_hour}PM" if opening_hour < 12 else f"{opening_hour-12}PM-{closing_hour-12}PM"

#     return (
#         f"{random_start_date.strftime('%A, %d %B %Y')} - "
#         f"{random_end_date.strftime('%A, %d %B %Y')} {time_range}"
#     )

# data = []
# for _ in range(10000):
#     address, coordinates = generate_random_address()
#     latitude, longitude = coordinates

#     entry = {
#         "private_id": f"PRI{random.randint(10000, 99999)}",
#         "name": f"Property {random.randint(1, 1000)}",
#         "address": address,
#         "city": address.split(", ")[-1],
#         "latitude": latitude,
#         "longitude": longitude,
#         "price_per_hour": round(random.uniform(1, 2), 2),
#         "capacity": random.randint(5, 10),
#         "available_space": random.randint(1, 5),
#         "special_access": random.choice(["garage", "basement", "storage room", "rooftop"]),
#         "landlord_id": generate_landlord_id(),
#         "opening_time": generate_opening_time()
#     }
#     data.append(entry)

# # Output the data in JSON format
# json_data = json.dumps(data, indent=4)
# json_data[:500]

# # Save the generated data to a JSON file
# with open('private_parking.json', 'w') as json_file:
#     json.dump(data, json_file, indent=4)

# %%
import random
import json
import datetime

# Load the JSON data (assuming you have the file path)
with open('landlord_data.json', 'r') as file:
    landlord_data = json.load(file)

def generate_landlord_id():
    # Randomly select a landlord_id from the JSON data
    return random.choice(landlord_data)['landlord_id']

def generate_random_address():
    # Streets and locations from various cities in Baden-Württemberg
    streets = [
        "Hauptstraße", "Schlossstraße", "Marktplatz", "Bahnhofstraße", "Karlsruher Straße",
        "Ludwigsburger Straße", "Heidelberger Straße", "Stuttgarter Straße", "Bodenseestraße",
        "Tübinger Straße", "Ulmer Straße", "Hegelstraße", "Goethestraße", "Mozartstraße",
        "Kantstraße", "Friedrichstraße", "Wilhelmstraße"
    ]
    house_numbers = range(1, 150)

    # List of cities in Baden-Württemberg and their coordinates (lat, lon)
    cities_with_coords = {
        "Stuttgart": (48.7758, 9.1829),
        "Karlsruhe": (49.0144, 8.4044),
        "Mannheim": (49.4875, 8.4647),
        "Freiburg": (47.9990, 7.8425),
        "Heidelberg": (49.3984, 8.6724),
        "Ulm": (48.4011, 9.9876),
        "Pforzheim": (48.8984, 8.7010),
        "Reutlingen": (48.4815, 9.2043),
        "Tübingen": (48.5204, 9.0568),
        "Ludwigsburg": (48.8982, 9.1941),
        "Esslingen": (48.7400, 9.3100),
        "Baden-Baden": (48.7591, 8.2400),
        "Konstanz": (47.6660, 9.1732),
        "Villingen-Schwenningen": (48.0732, 8.4920)
    }
    
    street = random.choice(streets)
    number = random.choice(house_numbers)

    # Randomly select a city and its coordinates
    city = random.choice(list(cities_with_coords.keys()))
    coordinates = cities_with_coords[city]
    
    return f"{street} {number}, {city}", coordinates

# def generate_opening_time():
#     start_date = datetime.datetime(2025, 1, 1)
#     end_date = datetime.datetime(2025, 12, 31)
#     delta = end_date - start_date

#     # Random start and end dates within the year
#     random_days = random.randint(0, delta.days)
#     random_start_date = start_date + datetime.timedelta(days=random_days)
#     random_end_date = random_start_date + datetime.timedelta(days=random.randint(1, 30))

#     # Generate random opening and closing times between 6 AM and 10 PM
#     opening_hour = random.randint(6, 21)  # Earliest opening time is 6 AM, latest is 9 PM
#     closing_hour = random.randint(opening_hour + 1, 22)  # Must close at least 1 hour later, latest is 10 PM

#     time_range = f"{opening_hour}AM-{closing_hour}PM" if opening_hour < 12 else f"{opening_hour-12}PM-{closing_hour-12}PM"

#     return (
#         f"{random_start_date.strftime('%A, %d %B %Y')} - "
#         f"{random_end_date.strftime('%A, %d %B %Y')} {time_range}"
#     )

# %%
import random
import datetime

def generate_opening_time():
    """Generates a random opening date and time between 6 AM and 9 PM."""
    start_date = datetime.datetime(2025, 1, 1)
    end_date = datetime.datetime(2025, 12, 31)
    delta = end_date - start_date

    # Randomly choose a start and end date within the year
    random_days = random.randint(0, delta.days)
    random_start_date = start_date + datetime.timedelta(days=random_days)
    random_end_date = random_start_date + datetime.timedelta(days=random.randint(1, 30))

    # Generate random opening time between 6 AM and 9 PM
    opening_hour = random.randint(6, 21)  # Earliest: 6 AM, Latest: 9 PM
    opening_minute = random.choice([0, 15, 30, 45])  # Quarter-hour increments

    return random_start_date, random_end_date, opening_hour, opening_minute

def generate_closing_time(opening_hour):
    """Generates a closing time that is at least 1 hour after the opening time and before 10 PM."""
    closing_hour = random.randint(opening_hour + 1, 22)  # Must be at least 1 hour later, max 10 PM
    closing_minute = random.choice([0, 15, 30, 45])  # Quarter-hour increments

    return closing_hour, closing_minute

def generate_open_days():
    """Generates random open days as an array (e.g., ['Monday', 'Tuesday'])."""
    days_of_week = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
    
    # Randomly select how many days the parking is open (1 to 7 days)
    num_days = random.randint(1, 7)
    
    # Randomly pick days without duplicates
    open_days = random.sample(days_of_week, num_days)
    
    return open_days

# %%
def generate_key_access_info():
    # Randomly select an access method
    access_methods = [
        "Key available at the front desk",
        "Access via key box with code (code: 1234)",
        "Access via smart lock with app",
        "Key can be picked up at the local office",
        "Please contact the landlord for access instructions"
    ]
    return random.choice(access_methods)

def generate_note_area():
    # Randomly generate some notes about parking lot conditions
    conditions = [
        "Parking lot in good condition, recently paved.",
        "Parking space may be tight due to ongoing construction.",
        "The space is well-lit but may be dusty in dry weather.",
        "Access may be limited during the night due to maintenance work.",
        "Lot is cleaned every Monday morning."
    ]
    return random.choice(conditions)

data = []

for _ in range(10000):
    address, coordinates = generate_random_address()
    latitude, longitude = coordinates

    # Generate opening time first
    start_date, end_date, opening_hour, opening_minute = generate_opening_time()
    
    # Generate closing time based on opening time
    closing_hour, closing_minute = generate_closing_time(opening_hour)

    entry = {
        "private_id": f"PRI{random.randint(10000, 99999)}",
        "name": f"Property {random.randint(1, 1000)}",
        "address": address,
        "latitude": latitude,
        "longitude": longitude,
        "price_per_hour": round(random.uniform(1, 2), 2),
        "capacity": random.randint(5, 10),
        "available_space": random.randint(1, 5),
        "special_access": random.choice(["garage", "basement", "storage room", "rooftop"]),
        "landlord_id": generate_landlord_id(),
        "opening_time": f"{opening_hour}:{opening_minute:02d}",  # Proper formatting
        "closing_time": f"{closing_hour}:{closing_minute:02d}",  # Proper formatting
        "open_days": generate_open_days(),  # NEW COLUMN: Open days as an array
        "city": address.split(", ")[-1],  
        "note_area": generate_note_area(),  
        "key_access_info": generate_key_access_info()
    }
    data.append(entry)

# %%
data
# Out:
# [{'private_id': 'PRI96852',
#   'name': 'Property 537',
#   'address': 'Wilhelmstraße 131, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.35,
#   'capacity': 9,
#   'available_space': 1,
#   'special_access': 'garage',
#   'landlord_id': 'LID61945',
#   'opening_time': '20:30',
#   'closing_time': '22:15',
#   'open_days': ['Wednesday', 'Monday', 'Friday', 'Saturday', 'Tuesday'],
#   'city': 'Freiburg',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI78296',
#   'name': 'Property 746',
#   'address': 'Hauptstraße 148, Heidelberg',
#   'latitude': 49.3984,
#   'longitude': 8.6724,
#   'price_per_hour': 1.78,
#   'capacity': 5,
#   'available_space': 2,
#   'special_access': 'basement',
#   'landlord_id': 'LID79084',
#   'opening_time': '19:00',
#   'closing_time': '21:30',
#   'open_days': ['Thursday', 'Monday', 'Saturday', 'Tuesday', 'Friday'],
#   'city': 'Heidelberg',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI14548',
#   'name': 'Property 989',
#   'address': 'Bahnhofstraße 110, Ludwigsburg',
#   'latitude': 48.8982,
#   'longitude': 9.1941,
#   'price_per_hour': 1.9,
#   'capacity': 6,
#   'available_space': 1,
#   'special_access': 'storage room',
#   'landlord_id': 'LID36864',
#   'opening_time': '19:15',
#   'closing_time': '22:15',
#   'open_days': ['Wednesday', 'Monday', 'Tuesday', 'Sunday', 'Thursday'],
#   'city': 'Ludwigsburg',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI40591',
#   'name': 'Property 341',
#   'address': 'Hegelstraße 123, Heidelberg',
#   'latitude': 49.3984,
#   'longitude': 8.6724,
#   'price_per_hour': 1.11,
#   'capacity': 5,
#   'available_space': 2,
#   'special_access': 'garage',
#   'landlord_id': 'LID15620',
#   'opening_time': '15:15',
#   'closing_time': '16:45',
#   'open_days': ['Sunday', 'Monday', 'Tuesday'],
#   'city': 'Heidelberg',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI78134',
#   'name': 'Property 587',
#   'address': 'Wilhelmstraße 52, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.94,
#   'capacity': 8,
#   'available_space': 4,
#   'special_access': 'garage',
#   'landlord_id': 'LID34987',
#   'opening_time': '21:45',
#   'closing_time': '22:45',
#   'open_days': ['Friday', 'Sunday'],
#   'city': 'Freiburg',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI96771',
#   'name': 'Property 437',
#   'address': 'Ludwigsburger Straße 88, Pforzheim',
#   'latitude': 48.8984,
#   'longitude': 8.701,
#   'price_per_hour': 1.45,
#   'capacity': 5,
#   'available_space': 5,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID45852',
#   'opening_time': '16:00',
#   'closing_time': '21:45',
#   'open_days': ['Friday',
#    'Tuesday',
#    'Sunday',
#    'Saturday',
#    'Wednesday',
#    'Thursday'],
#   'city': 'Pforzheim',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI86367',
#   'name': 'Property 782',
#   'address': 'Heidelberger Straße 48, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.68,
#   'capacity': 5,
#   'available_space': 4,
#   'special_access': 'basement',
#   'landlord_id': 'LID55907',
#   'opening_time': '9:30',
#   'closing_time': '12:15',
#   'open_days': ['Saturday', 'Tuesday', 'Wednesday', 'Sunday', 'Thursday'],
#   'city': 'Freiburg',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI20204',
#   'name': 'Property 19',
#   'address': 'Kantstraße 93, Konstanz',
#   'latitude': 47.666,
#   'longitude': 9.1732,
#   'price_per_hour': 1.24,
#   'capacity': 7,
#   'available_space': 2,
#   'special_access': 'basement',
#   'landlord_id': 'LID35179',
#   'opening_time': '21:15',
#   'closing_time': '22:00',
#   'open_days': ['Friday', 'Sunday', 'Tuesday'],
#   'city': 'Konstanz',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI63120',
#   'name': 'Property 674',
#   'address': 'Goethestraße 149, Tübingen',
#   'latitude': 48.5204,
#   'longitude': 9.0568,
#   'price_per_hour': 1.06,
#   'capacity': 10,
#   'available_space': 5,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID32799',
#   'opening_time': '9:30',
#   'closing_time': '14:45',
#   'open_days': ['Thursday',
#    'Saturday',
#    'Tuesday',
#    'Friday',
#    'Sunday',
#    'Wednesday'],
#   'city': 'Tübingen',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI39717',
#   'name': 'Property 896',
#   'address': 'Mozartstraße 84, Stuttgart',
#   'latitude': 48.7758,
#   'longitude': 9.1829,
#   'price_per_hour': 1.36,
#   'capacity': 9,
#   'available_space': 5,
#   'special_access': 'garage',
#   'landlord_id': 'LID47972',
#   'opening_time': '9:00',
#   'closing_time': '13:45',
#   'open_days': ['Sunday'],
#   'city': 'Stuttgart',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI30270',
#   'name': 'Property 170',
#   'address': 'Hauptstraße 25, Konstanz',
#   'latitude': 47.666,
#   'longitude': 9.1732,
#   'price_per_hour': 1.76,
#   'capacity': 7,
#   'available_space': 2,
#   'special_access': 'basement',
#   'landlord_id': 'LID10559',
#   'opening_time': '20:15',
#   'closing_time': '22:00',
#   'open_days': ['Thursday', 'Friday'],
#   'city': 'Konstanz',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI74926',
#   'name': 'Property 983',
#   'address': 'Bahnhofstraße 128, Heidelberg',
#   'latitude': 49.3984,
#   'longitude': 8.6724,
#   'price_per_hour': 1.72,
#   'capacity': 8,
#   'available_space': 1,
#   'special_access': 'basement',
#   'landlord_id': 'LID26233',
#   'opening_time': '12:30',
#   'closing_time': '20:15',
#   'open_days': ['Friday',
#    'Sunday',
#    'Wednesday',
#    'Thursday',
#    'Tuesday',
#    'Monday'],
#   'city': 'Heidelberg',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI65613',
#   'name': 'Property 124',
#   'address': 'Friedrichstraße 15, Ludwigsburg',
#   'latitude': 48.8982,
#   'longitude': 9.1941,
#   'price_per_hour': 1.01,
#   'capacity': 6,
#   'available_space': 5,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID47512',
#   'opening_time': '19:15',
#   'closing_time': '22:00',
#   'open_days': ['Friday', 'Sunday'],
#   'city': 'Ludwigsburg',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI45920',
#   'name': 'Property 135',
#   'address': 'Heidelberger Straße 140, Heidelberg',
#   'latitude': 49.3984,
#   'longitude': 8.6724,
#   'price_per_hour': 1.61,
#   'capacity': 6,
#   'available_space': 3,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID20446',
#   'opening_time': '9:00',
#   'closing_time': '15:00',
#   'open_days': ['Monday',
#    'Sunday',
#    'Wednesday',
#    'Tuesday',
#    'Saturday',
#    'Friday'],
#   'city': 'Heidelberg',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI38246',
#   'name': 'Property 603',
#   'address': 'Ulmer Straße 65, Mannheim',
#   'latitude': 49.4875,
#   'longitude': 8.4647,
#   'price_per_hour': 1.24,
#   'capacity': 5,
#   'available_space': 4,
#   'special_access': 'storage room',
#   'landlord_id': 'LID76310',
#   'opening_time': '7:15',
#   'closing_time': '18:00',
#   'open_days': ['Wednesday', 'Thursday', 'Saturday', 'Friday'],
#   'city': 'Mannheim',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI36252',
#   'name': 'Property 224',
#   'address': 'Hegelstraße 116, Heidelberg',
#   'latitude': 49.3984,
#   'longitude': 8.6724,
#   'price_per_hour': 1.03,
#   'capacity': 6,
#   'available_space': 1,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID91863',
#   'opening_time': '13:30',
#   'closing_time': '22:00',
#   'open_days': ['Thursday',
#    'Sunday',
#    'Monday',
#    'Tuesday',
#    'Saturday',
#    'Wednesday'],
#   'city': 'Heidelberg',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI72877',
#   'name': 'Property 356',
#   'address': 'Ulmer Straße 56, Villingen-Schwenningen',
#   'latitude': 48.0732,
#   'longitude': 8.492,
#   'price_per_hour': 1.96,
#   'capacity': 10,
#   'available_space': 1,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID60284',
#   'opening_time': '12:00',
#   'closing_time': '21:15',
#   'open_days': ['Monday', 'Saturday', 'Friday'],
#   'city': 'Villingen-Schwenningen',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI33830',
#   'name': 'Property 525',
#   'address': 'Kantstraße 142, Tübingen',
#   'latitude': 48.5204,
#   'longitude': 9.0568,
#   'price_per_hour': 1.56,
#   'capacity': 5,
#   'available_space': 1,
#   'special_access': 'basement',
#   'landlord_id': 'LID26068',
#   'opening_time': '11:15',
#   'closing_time': '17:00',
#   'open_days': ['Tuesday',
#    'Wednesday',
#    'Monday',
#    'Friday',
#    'Thursday',
#    'Sunday',
#    'Saturday'],
#   'city': 'Tübingen',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI38189',
#   'name': 'Property 815',
#   'address': 'Hegelstraße 39, Ulm',
#   'latitude': 48.4011,
#   'longitude': 9.9876,
#   'price_per_hour': 1.63,
#   'capacity': 10,
#   'available_space': 4,
#   'special_access': 'storage room',
#   'landlord_id': 'LID92727',
#   'opening_time': '6:15',
#   'closing_time': '9:30',
#   'open_days': ['Tuesday', 'Thursday'],
#   'city': 'Ulm',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI32877',
#   'name': 'Property 519',
#   'address': 'Goethestraße 115, Baden-Baden',
#   'latitude': 48.7591,
#   'longitude': 8.24,
#   'price_per_hour': 1.64,
#   'capacity': 5,
#   'available_space': 3,
#   'special_access': 'basement',
#   'landlord_id': 'LID22556',
#   'opening_time': '12:30',
#   'closing_time': '22:30',
#   'open_days': ['Tuesday', 'Thursday', 'Saturday'],
#   'city': 'Baden-Baden',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI48583',
#   'name': 'Property 369',
#   'address': 'Ulmer Straße 104, Karlsruhe',
#   'latitude': 49.0144,
#   'longitude': 8.4044,
#   'price_per_hour': 1.1,
#   'capacity': 6,
#   'available_space': 2,
#   'special_access': 'basement',
#   'landlord_id': 'LID34178',
#   'opening_time': '17:15',
#   'closing_time': '19:00',
#   'open_days': ['Tuesday', 'Friday', 'Saturday', 'Monday', 'Sunday'],
#   'city': 'Karlsruhe',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI55410',
#   'name': 'Property 634',
#   'address': 'Bahnhofstraße 85, Mannheim',
#   'latitude': 49.4875,
#   'longitude': 8.4647,
#   'price_per_hour': 1.19,
#   'capacity': 10,
#   'available_space': 4,
#   'special_access': 'basement',
#   'landlord_id': 'LID26754',
#   'opening_time': '18:00',
#   'closing_time': '20:45',
#   'open_days': ['Saturday', 'Friday'],
#   'city': 'Mannheim',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI72339',
#   'name': 'Property 984',
#   'address': 'Karlsruher Straße 3, Mannheim',
#   'latitude': 49.4875,
#   'longitude': 8.4647,
#   'price_per_hour': 1.84,
#   'capacity': 9,
#   'available_space': 3,
#   'special_access': 'storage room',
#   'landlord_id': 'LID62498',
#   'opening_time': '7:45',
#   'closing_time': '14:30',
#   'open_days': ['Sunday'],
#   'city': 'Mannheim',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI88779',
#   'name': 'Property 763',
#   'address': 'Ulmer Straße 121, Villingen-Schwenningen',
#   'latitude': 48.0732,
#   'longitude': 8.492,
#   'price_per_hour': 1.86,
#   'capacity': 5,
#   'available_space': 2,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID11688',
#   'opening_time': '11:15',
#   'closing_time': '19:30',
#   'open_days': ['Friday',
#    'Tuesday',
#    'Saturday',
#    'Thursday',
#    'Wednesday',
#    'Sunday'],
#   'city': 'Villingen-Schwenningen',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI39919',
#   'name': 'Property 102',
#   'address': 'Karlsruher Straße 74, Ulm',
#   'latitude': 48.4011,
#   'longitude': 9.9876,
#   'price_per_hour': 1.0,
#   'capacity': 10,
#   'available_space': 3,
#   'special_access': 'garage',
#   'landlord_id': 'LID61840',
#   'opening_time': '17:45',
#   'closing_time': '22:00',
#   'open_days': ['Monday', 'Saturday', 'Wednesday', 'Friday'],
#   'city': 'Ulm',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI49466',
#   'name': 'Property 959',
#   'address': 'Stuttgarter Straße 135, Baden-Baden',
#   'latitude': 48.7591,
#   'longitude': 8.24,
#   'price_per_hour': 1.84,
#   'capacity': 8,
#   'available_space': 3,
#   'special_access': 'storage room',
#   'landlord_id': 'LID51138',
#   'opening_time': '11:15',
#   'closing_time': '14:00',
#   'open_days': ['Tuesday', 'Friday'],
#   'city': 'Baden-Baden',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI68011',
#   'name': 'Property 8',
#   'address': 'Ludwigsburger Straße 134, Esslingen',
#   'latitude': 48.74,
#   'longitude': 9.31,
#   'price_per_hour': 1.66,
#   'capacity': 8,
#   'available_space': 1,
#   'special_access': 'garage',
#   'landlord_id': 'LID54641',
#   'opening_time': '19:15',
#   'closing_time': '22:30',
#   'open_days': ['Friday', 'Thursday', 'Sunday', 'Monday'],
#   'city': 'Esslingen',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI95981',
#   'name': 'Property 633',
#   'address': 'Bodenseestraße 12, Karlsruhe',
#   'latitude': 49.0144,
#   'longitude': 8.4044,
#   'price_per_hour': 1.39,
#   'capacity': 5,
#   'available_space': 3,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID62339',
#   'opening_time': '9:15',
#   'closing_time': '20:00',
#   'open_days': ['Thursday', 'Monday', 'Tuesday'],
#   'city': 'Karlsruhe',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI23776',
#   'name': 'Property 501',
#   'address': 'Tübinger Straße 131, Villingen-Schwenningen',
#   'latitude': 48.0732,
#   'longitude': 8.492,
#   'price_per_hour': 1.76,
#   'capacity': 10,
#   'available_space': 5,
#   'special_access': 'basement',
#   'landlord_id': 'LID37182',
#   'opening_time': '10:00',
#   'closing_time': '11:15',
#   'open_days': ['Monday'],
#   'city': 'Villingen-Schwenningen',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI97831',
#   'name': 'Property 488',
#   'address': 'Ulmer Straße 86, Esslingen',
#   'latitude': 48.74,
#   'longitude': 9.31,
#   'price_per_hour': 1.09,
#   'capacity': 8,
#   'available_space': 5,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID25307',
#   'opening_time': '11:30',
#   'closing_time': '15:00',
#   'open_days': ['Wednesday',
#    'Monday',
#    'Sunday',
#    'Friday',
#    'Saturday',
#    'Tuesday',
#    'Thursday'],
#   'city': 'Esslingen',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI99411',
#   'name': 'Property 177',
#   'address': 'Kantstraße 35, Stuttgart',
#   'latitude': 48.7758,
#   'longitude': 9.1829,
#   'price_per_hour': 1.37,
#   'capacity': 8,
#   'available_space': 5,
#   'special_access': 'storage room',
#   'landlord_id': 'LID10307',
#   'opening_time': '13:15',
#   'closing_time': '14:45',
#   'open_days': ['Thursday', 'Saturday', 'Sunday', 'Tuesday', 'Wednesday'],
#   'city': 'Stuttgart',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI61396',
#   'name': 'Property 391',
#   'address': 'Bahnhofstraße 86, Tübingen',
#   'latitude': 48.5204,
#   'longitude': 9.0568,
#   'price_per_hour': 1.65,
#   'capacity': 9,
#   'available_space': 5,
#   'special_access': 'basement',
#   'landlord_id': 'LID78646',
#   'opening_time': '10:45',
#   'closing_time': '21:30',
#   'open_days': ['Thursday'],
#   'city': 'Tübingen',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI21224',
#   'name': 'Property 821',
#   'address': 'Goethestraße 57, Villingen-Schwenningen',
#   'latitude': 48.0732,
#   'longitude': 8.492,
#   'price_per_hour': 1.88,
#   'capacity': 6,
#   'available_space': 4,
#   'special_access': 'garage',
#   'landlord_id': 'LID13477',
#   'opening_time': '13:45',
#   'closing_time': '20:00',
#   'open_days': ['Thursday',
#    'Saturday',
#    'Sunday',
#    'Tuesday',
#    'Friday',
#    'Monday'],
#   'city': 'Villingen-Schwenningen',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI31338',
#   'name': 'Property 948',
#   'address': 'Mozartstraße 143, Tübingen',
#   'latitude': 48.5204,
#   'longitude': 9.0568,
#   'price_per_hour': 1.2,
#   'capacity': 5,
#   'available_space': 1,
#   'special_access': 'storage room',
#   'landlord_id': 'LID21731',
#   'opening_time': '9:15',
#   'closing_time': '22:00',
#   'open_days': ['Friday', 'Wednesday', 'Thursday', 'Sunday'],
#   'city': 'Tübingen',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI64184',
#   'name': 'Property 943',
#   'address': 'Kantstraße 100, Karlsruhe',
#   'latitude': 49.0144,
#   'longitude': 8.4044,
#   'price_per_hour': 1.74,
#   'capacity': 10,
#   'available_space': 3,
#   'special_access': 'garage',
#   'landlord_id': 'LID15677',
#   'opening_time': '10:00',
#   'closing_time': '21:45',
#   'open_days': ['Sunday', 'Monday', 'Saturday', 'Wednesday'],
#   'city': 'Karlsruhe',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI90440',
#   'name': 'Property 47',
#   'address': 'Heidelberger Straße 11, Esslingen',
#   'latitude': 48.74,
#   'longitude': 9.31,
#   'price_per_hour': 1.15,
#   'capacity': 8,
#   'available_space': 4,
#   'special_access': 'storage room',
#   'landlord_id': 'LID57244',
#   'opening_time': '21:45',
#   'closing_time': '22:30',
#   'open_days': ['Friday',
#    'Tuesday',
#    'Monday',
#    'Thursday',
#    'Wednesday',
#    'Saturday'],
#   'city': 'Esslingen',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI26415',
#   'name': 'Property 155',
#   'address': 'Bodenseestraße 122, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.34,
#   'capacity': 9,
#   'available_space': 3,
#   'special_access': 'garage',
#   'landlord_id': 'LID70724',
#   'opening_time': '9:45',
#   'closing_time': '10:45',
#   'open_days': ['Thursday',
#    'Friday',
#    'Sunday',
#    'Monday',
#    'Wednesday',
#    'Tuesday'],
#   'city': 'Freiburg',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI88482',
#   'name': 'Property 594',
#   'address': 'Hauptstraße 88, Reutlingen',
#   'latitude': 48.4815,
#   'longitude': 9.2043,
#   'price_per_hour': 1.16,
#   'capacity': 7,
#   'available_space': 1,
#   'special_access': 'basement',
#   'landlord_id': 'LID20287',
#   'opening_time': '17:45',
#   'closing_time': '22:30',
#   'open_days': ['Saturday', 'Thursday', 'Friday', 'Sunday'],
#   'city': 'Reutlingen',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI24258',
#   'name': 'Property 904',
#   'address': 'Tübinger Straße 35, Ulm',
#   'latitude': 48.4011,
#   'longitude': 9.9876,
#   'price_per_hour': 1.86,
#   'capacity': 7,
#   'available_space': 3,
#   'special_access': 'basement',
#   'landlord_id': 'LID46376',
#   'opening_time': '17:00',
#   'closing_time': '18:00',
#   'open_days': ['Thursday', 'Saturday'],
#   'city': 'Ulm',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI17987',
#   'name': 'Property 397',
#   'address': 'Stuttgarter Straße 116, Stuttgart',
#   'latitude': 48.7758,
#   'longitude': 9.1829,
#   'price_per_hour': 1.05,
#   'capacity': 9,
#   'available_space': 2,
#   'special_access': 'storage room',
#   'landlord_id': 'LID14476',
#   'opening_time': '7:15',
#   'closing_time': '9:45',
#   'open_days': ['Sunday', 'Saturday', 'Friday'],
#   'city': 'Stuttgart',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI21179',
#   'name': 'Property 319',
#   'address': 'Hauptstraße 35, Heidelberg',
#   'latitude': 49.3984,
#   'longitude': 8.6724,
#   'price_per_hour': 1.79,
#   'capacity': 10,
#   'available_space': 2,
#   'special_access': 'storage room',
#   'landlord_id': 'LID61388',
#   'opening_time': '8:00',
#   'closing_time': '11:30',
#   'open_days': ['Monday'],
#   'city': 'Heidelberg',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI79062',
#   'name': 'Property 684',
#   'address': 'Karlsruher Straße 7, Karlsruhe',
#   'latitude': 49.0144,
#   'longitude': 8.4044,
#   'price_per_hour': 1.57,
#   'capacity': 10,
#   'available_space': 4,
#   'special_access': 'garage',
#   'landlord_id': 'LID76148',
#   'opening_time': '6:00',
#   'closing_time': '15:15',
#   'open_days': ['Thursday', 'Tuesday', 'Sunday'],
#   'city': 'Karlsruhe',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI73400',
#   'name': 'Property 483',
#   'address': 'Stuttgarter Straße 14, Ludwigsburg',
#   'latitude': 48.8982,
#   'longitude': 9.1941,
#   'price_per_hour': 1.95,
#   'capacity': 7,
#   'available_space': 3,
#   'special_access': 'garage',
#   'landlord_id': 'LID24612',
#   'opening_time': '8:30',
#   'closing_time': '18:00',
#   'open_days': ['Tuesday', 'Wednesday', 'Friday', 'Thursday'],
#   'city': 'Ludwigsburg',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI94942',
#   'name': 'Property 907',
#   'address': 'Hegelstraße 94, Konstanz',
#   'latitude': 47.666,
#   'longitude': 9.1732,
#   'price_per_hour': 1.25,
#   'capacity': 10,
#   'available_space': 5,
#   'special_access': 'garage',
#   'landlord_id': 'LID38127',
#   'opening_time': '19:00',
#   'closing_time': '21:30',
#   'open_days': ['Monday',
#    'Wednesday',
#    'Sunday',
#    'Tuesday',
#    'Thursday',
#    'Friday',
#    'Saturday'],
#   'city': 'Konstanz',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI28079',
#   'name': 'Property 530',
#   'address': 'Goethestraße 33, Pforzheim',
#   'latitude': 48.8984,
#   'longitude': 8.701,
#   'price_per_hour': 1.76,
#   'capacity': 8,
#   'available_space': 4,
#   'special_access': 'storage room',
#   'landlord_id': 'LID67165',
#   'opening_time': '20:30',
#   'closing_time': '21:00',
#   'open_days': ['Sunday',
#    'Tuesday',
#    'Wednesday',
#    'Friday',
#    'Saturday',
#    'Monday',
#    'Thursday'],
#   'city': 'Pforzheim',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI88154',
#   'name': 'Property 574',
#   'address': 'Bodenseestraße 91, Pforzheim',
#   'latitude': 48.8984,
#   'longitude': 8.701,
#   'price_per_hour': 1.55,
#   'capacity': 10,
#   'available_space': 3,
#   'special_access': 'garage',
#   'landlord_id': 'LID87122',
#   'opening_time': '12:00',
#   'closing_time': '22:00',
#   'open_days': ['Tuesday'],
#   'city': 'Pforzheim',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI16282',
#   'name': 'Property 195',
#   'address': 'Kantstraße 131, Mannheim',
#   'latitude': 49.4875,
#   'longitude': 8.4647,
#   'price_per_hour': 1.05,
#   'capacity': 7,
#   'available_space': 5,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID34186',
#   'opening_time': '7:00',
#   'closing_time': '14:00',
#   'open_days': ['Friday',
#    'Monday',
#    'Tuesday',
#    'Wednesday',
#    'Saturday',
#    'Sunday'],
#   'city': 'Mannheim',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI96782',
#   'name': 'Property 530',
#   'address': 'Schlossstraße 52, Esslingen',
#   'latitude': 48.74,
#   'longitude': 9.31,
#   'price_per_hour': 1.3,
#   'capacity': 10,
#   'available_space': 5,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID18127',
#   'opening_time': '8:30',
#   'closing_time': '14:00',
#   'open_days': ['Sunday', 'Friday'],
#   'city': 'Esslingen',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI85652',
#   'name': 'Property 166',
#   'address': 'Bahnhofstraße 43, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.38,
#   'capacity': 8,
#   'available_space': 1,
#   'special_access': 'garage',
#   'landlord_id': 'LID52887',
#   'opening_time': '9:15',
#   'closing_time': '13:45',
#   'open_days': ['Friday', 'Monday'],
#   'city': 'Freiburg',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI70681',
#   'name': 'Property 224',
#   'address': 'Hegelstraße 108, Villingen-Schwenningen',
#   'latitude': 48.0732,
#   'longitude': 8.492,
#   'price_per_hour': 1.04,
#   'capacity': 5,
#   'available_space': 5,
#   'special_access': 'storage room',
#   'landlord_id': 'LID45098',
#   'opening_time': '19:30',
#   'closing_time': '21:00',
#   'open_days': ['Friday'],
#   'city': 'Villingen-Schwenningen',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI43091',
#   'name': 'Property 406',
#   'address': 'Mozartstraße 91, Ludwigsburg',
#   'latitude': 48.8982,
#   'longitude': 9.1941,
#   'price_per_hour': 1.18,
#   'capacity': 5,
#   'available_space': 4,
#   'special_access': 'basement',
#   'landlord_id': 'LID49236',
#   'opening_time': '10:15',
#   'closing_time': '11:00',
#   'open_days': ['Wednesday', 'Thursday'],
#   'city': 'Ludwigsburg',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI68191',
#   'name': 'Property 563',
#   'address': 'Tübinger Straße 118, Ulm',
#   'latitude': 48.4011,
#   'longitude': 9.9876,
#   'price_per_hour': 1.78,
#   'capacity': 7,
#   'available_space': 2,
#   'special_access': 'garage',
#   'landlord_id': 'LID99353',
#   'opening_time': '7:30',
#   'closing_time': '14:00',
#   'open_days': ['Wednesday', 'Tuesday', 'Thursday'],
#   'city': 'Ulm',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI24073',
#   'name': 'Property 232',
#   'address': 'Ludwigsburger Straße 104, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.14,
#   'capacity': 8,
#   'available_space': 3,
#   'special_access': 'storage room',
#   'landlord_id': 'LID48669',
#   'opening_time': '14:45',
#   'closing_time': '15:00',
#   'open_days': ['Friday',
#    'Thursday',
#    'Saturday',
#    'Sunday',
#    'Wednesday',
#    'Monday'],
#   'city': 'Freiburg',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI98897',
#   'name': 'Property 727',
#   'address': 'Tübinger Straße 53, Stuttgart',
#   'latitude': 48.7758,
#   'longitude': 9.1829,
#   'price_per_hour': 1.93,
#   'capacity': 5,
#   'available_space': 3,
#   'special_access': 'garage',
#   'landlord_id': 'LID41767',
#   'opening_time': '13:15',
#   'closing_time': '15:00',
#   'open_days': ['Saturday'],
#   'city': 'Stuttgart',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI81977',
#   'name': 'Property 479',
#   'address': 'Bahnhofstraße 73, Tübingen',
#   'latitude': 48.5204,
#   'longitude': 9.0568,
#   'price_per_hour': 1.2,
#   'capacity': 9,
#   'available_space': 4,
#   'special_access': 'garage',
#   'landlord_id': 'LID38521',
#   'opening_time': '14:45',
#   'closing_time': '17:30',
#   'open_days': ['Thursday',
#    'Friday',
#    'Saturday',
#    'Monday',
#    'Sunday',
#    'Tuesday'],
#   'city': 'Tübingen',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI29298',
#   'name': 'Property 427',
#   'address': 'Schlossstraße 24, Esslingen',
#   'latitude': 48.74,
#   'longitude': 9.31,
#   'price_per_hour': 1.01,
#   'capacity': 8,
#   'available_space': 1,
#   'special_access': 'garage',
#   'landlord_id': 'LID93200',
#   'opening_time': '16:15',
#   'closing_time': '20:00',
#   'open_days': ['Monday', 'Tuesday', 'Thursday'],
#   'city': 'Esslingen',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI41479',
#   'name': 'Property 772',
#   'address': 'Bahnhofstraße 109, Reutlingen',
#   'latitude': 48.4815,
#   'longitude': 9.2043,
#   'price_per_hour': 1.8,
#   'capacity': 6,
#   'available_space': 2,
#   'special_access': 'storage room',
#   'landlord_id': 'LID61190',
#   'opening_time': '15:00',
#   'closing_time': '19:45',
#   'open_days': ['Tuesday', 'Thursday', 'Sunday', 'Saturday'],
#   'city': 'Reutlingen',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI77496',
#   'name': 'Property 658',
#   'address': 'Bahnhofstraße 138, Ludwigsburg',
#   'latitude': 48.8982,
#   'longitude': 9.1941,
#   'price_per_hour': 1.63,
#   'capacity': 6,
#   'available_space': 4,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID18028',
#   'opening_time': '11:15',
#   'closing_time': '13:45',
#   'open_days': ['Wednesday', 'Sunday', 'Monday'],
#   'city': 'Ludwigsburg',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI56519',
#   'name': 'Property 71',
#   'address': 'Stuttgarter Straße 66, Reutlingen',
#   'latitude': 48.4815,
#   'longitude': 9.2043,
#   'price_per_hour': 1.71,
#   'capacity': 8,
#   'available_space': 2,
#   'special_access': 'basement',
#   'landlord_id': 'LID23022',
#   'opening_time': '12:15',
#   'closing_time': '20:00',
#   'open_days': ['Thursday', 'Monday', 'Tuesday'],
#   'city': 'Reutlingen',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI85257',
#   'name': 'Property 568',
#   'address': 'Karlsruher Straße 106, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.71,
#   'capacity': 8,
#   'available_space': 5,
#   'special_access': 'basement',
#   'landlord_id': 'LID84627',
#   'opening_time': '19:30',
#   'closing_time': '21:15',
#   'open_days': ['Tuesday',
#    'Thursday',
#    'Friday',
#    'Monday',
#    'Saturday',
#    'Sunday'],
#   'city': 'Freiburg',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI36637',
#   'name': 'Property 342',
#   'address': 'Bahnhofstraße 57, Reutlingen',
#   'latitude': 48.4815,
#   'longitude': 9.2043,
#   'price_per_hour': 1.21,
#   'capacity': 7,
#   'available_space': 5,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID68321',
#   'opening_time': '10:45',
#   'closing_time': '13:45',
#   'open_days': ['Tuesday'],
#   'city': 'Reutlingen',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI47005',
#   'name': 'Property 712',
#   'address': 'Hegelstraße 103, Reutlingen',
#   'latitude': 48.4815,
#   'longitude': 9.2043,
#   'price_per_hour': 1.17,
#   'capacity': 7,
#   'available_space': 5,
#   'special_access': 'garage',
#   'landlord_id': 'LID50490',
#   'opening_time': '21:00',
#   'closing_time': '22:00',
#   'open_days': ['Saturday',
#    'Thursday',
#    'Tuesday',
#    'Monday',
#    'Friday',
#    'Wednesday'],
#   'city': 'Reutlingen',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI40118',
#   'name': 'Property 989',
#   'address': 'Hegelstraße 61, Konstanz',
#   'latitude': 47.666,
#   'longitude': 9.1732,
#   'price_per_hour': 1.66,
#   'capacity': 9,
#   'available_space': 4,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID80518',
#   'opening_time': '10:15',
#   'closing_time': '20:30',
#   'open_days': ['Sunday', 'Wednesday', 'Tuesday', 'Monday', 'Thursday'],
#   'city': 'Konstanz',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI88844',
#   'name': 'Property 658',
#   'address': 'Mozartstraße 64, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.66,
#   'capacity': 5,
#   'available_space': 3,
#   'special_access': 'garage',
#   'landlord_id': 'LID31647',
#   'opening_time': '13:30',
#   'closing_time': '17:30',
#   'open_days': ['Tuesday', 'Friday', 'Sunday'],
#   'city': 'Freiburg',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI18550',
#   'name': 'Property 140',
#   'address': 'Karlsruher Straße 96, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.24,
#   'capacity': 7,
#   'available_space': 1,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID49245',
#   'opening_time': '18:00',
#   'closing_time': '22:45',
#   'open_days': ['Saturday', 'Sunday', 'Tuesday', 'Thursday'],
#   'city': 'Freiburg',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI39553',
#   'name': 'Property 810',
#   'address': 'Bahnhofstraße 99, Heidelberg',
#   'latitude': 49.3984,
#   'longitude': 8.6724,
#   'price_per_hour': 1.03,
#   'capacity': 8,
#   'available_space': 2,
#   'special_access': 'storage room',
#   'landlord_id': 'LID10012',
#   'opening_time': '18:45',
#   'closing_time': '22:30',
#   'open_days': ['Thursday'],
#   'city': 'Heidelberg',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI80224',
#   'name': 'Property 231',
#   'address': 'Hauptstraße 1, Ulm',
#   'latitude': 48.4011,
#   'longitude': 9.9876,
#   'price_per_hour': 1.93,
#   'capacity': 10,
#   'available_space': 2,
#   'special_access': 'basement',
#   'landlord_id': 'LID22782',
#   'opening_time': '19:15',
#   'closing_time': '21:00',
#   'open_days': ['Tuesday', 'Thursday', 'Sunday'],
#   'city': 'Ulm',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI74554',
#   'name': 'Property 377',
#   'address': 'Marktplatz 87, Esslingen',
#   'latitude': 48.74,
#   'longitude': 9.31,
#   'price_per_hour': 1.11,
#   'capacity': 10,
#   'available_space': 3,
#   'special_access': 'basement',
#   'landlord_id': 'LID61589',
#   'opening_time': '14:45',
#   'closing_time': '19:15',
#   'open_days': ['Saturday', 'Monday', 'Friday'],
#   'city': 'Esslingen',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI69365',
#   'name': 'Property 866',
#   'address': 'Mozartstraße 57, Heidelberg',
#   'latitude': 49.3984,
#   'longitude': 8.6724,
#   'price_per_hour': 1.02,
#   'capacity': 6,
#   'available_space': 3,
#   'special_access': 'garage',
#   'landlord_id': 'LID45929',
#   'opening_time': '9:30',
#   'closing_time': '20:30',
#   'open_days': ['Thursday'],
#   'city': 'Heidelberg',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI61047',
#   'name': 'Property 838',
#   'address': 'Hegelstraße 101, Esslingen',
#   'latitude': 48.74,
#   'longitude': 9.31,
#   'price_per_hour': 1.27,
#   'capacity': 10,
#   'available_space': 4,
#   'special_access': 'basement',
#   'landlord_id': 'LID73795',
#   'opening_time': '20:15',
#   'closing_time': '21:45',
#   'open_days': ['Monday'],
#   'city': 'Esslingen',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI77143',
#   'name': 'Property 828',
#   'address': 'Wilhelmstraße 112, Karlsruhe',
#   'latitude': 49.0144,
#   'longitude': 8.4044,
#   'price_per_hour': 1.98,
#   'capacity': 7,
#   'available_space': 5,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID58062',
#   'opening_time': '11:45',
#   'closing_time': '12:30',
#   'open_days': ['Wednesday',
#    'Sunday',
#    'Monday',
#    'Thursday',
#    'Friday',
#    'Saturday'],
#   'city': 'Karlsruhe',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI67289',
#   'name': 'Property 720',
#   'address': 'Karlsruher Straße 50, Esslingen',
#   'latitude': 48.74,
#   'longitude': 9.31,
#   'price_per_hour': 1.86,
#   'capacity': 6,
#   'available_space': 5,
#   'special_access': 'garage',
#   'landlord_id': 'LID44675',
#   'opening_time': '6:00',
#   'closing_time': '9:30',
#   'open_days': ['Thursday', 'Monday', 'Wednesday', 'Friday'],
#   'city': 'Esslingen',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI85609',
#   'name': 'Property 529',
#   'address': 'Ulmer Straße 93, Ulm',
#   'latitude': 48.4011,
#   'longitude': 9.9876,
#   'price_per_hour': 1.77,
#   'capacity': 7,
#   'available_space': 4,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID83846',
#   'opening_time': '21:45',
#   'closing_time': '22:45',
#   'open_days': ['Wednesday',
#    'Thursday',
#    'Monday',
#    'Friday',
#    'Tuesday',
#    'Saturday',
#    'Sunday'],
#   'city': 'Ulm',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI62125',
#   'name': 'Property 647',
#   'address': 'Ludwigsburger Straße 110, Mannheim',
#   'latitude': 49.4875,
#   'longitude': 8.4647,
#   'price_per_hour': 1.61,
#   'capacity': 8,
#   'available_space': 2,
#   'special_access': 'basement',
#   'landlord_id': 'LID76903',
#   'opening_time': '21:15',
#   'closing_time': '22:45',
#   'open_days': ['Sunday', 'Saturday', 'Monday', 'Wednesday', 'Thursday'],
#   'city': 'Mannheim',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI52434',
#   'name': 'Property 76',
#   'address': 'Stuttgarter Straße 28, Villingen-Schwenningen',
#   'latitude': 48.0732,
#   'longitude': 8.492,
#   'price_per_hour': 1.24,
#   'capacity': 6,
#   'available_space': 1,
#   'special_access': 'basement',
#   'landlord_id': 'LID99353',
#   'opening_time': '17:45',
#   'closing_time': '20:45',
#   'open_days': ['Wednesday', 'Thursday'],
#   'city': 'Villingen-Schwenningen',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI82621',
#   'name': 'Property 528',
#   'address': 'Mozartstraße 135, Baden-Baden',
#   'latitude': 48.7591,
#   'longitude': 8.24,
#   'price_per_hour': 1.63,
#   'capacity': 7,
#   'available_space': 3,
#   'special_access': 'garage',
#   'landlord_id': 'LID80193',
#   'opening_time': '18:30',
#   'closing_time': '22:30',
#   'open_days': ['Wednesday', 'Monday', 'Sunday', 'Saturday'],
#   'city': 'Baden-Baden',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI33967',
#   'name': 'Property 223',
#   'address': 'Hegelstraße 64, Esslingen',
#   'latitude': 48.74,
#   'longitude': 9.31,
#   'price_per_hour': 1.2,
#   'capacity': 8,
#   'available_space': 2,
#   'special_access': 'basement',
#   'landlord_id': 'LID50363',
#   'opening_time': '14:30',
#   'closing_time': '21:30',
#   'open_days': ['Wednesday',
#    'Thursday',
#    'Friday',
#    'Tuesday',
#    'Saturday',
#    'Monday'],
#   'city': 'Esslingen',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI88497',
#   'name': 'Property 637',
#   'address': 'Friedrichstraße 141, Heidelberg',
#   'latitude': 49.3984,
#   'longitude': 8.6724,
#   'price_per_hour': 1.68,
#   'capacity': 9,
#   'available_space': 2,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID96131',
#   'opening_time': '11:15',
#   'closing_time': '12:45',
#   'open_days': ['Saturday', 'Thursday'],
#   'city': 'Heidelberg',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI19730',
#   'name': 'Property 526',
#   'address': 'Bahnhofstraße 76, Mannheim',
#   'latitude': 49.4875,
#   'longitude': 8.4647,
#   'price_per_hour': 1.68,
#   'capacity': 10,
#   'available_space': 5,
#   'special_access': 'basement',
#   'landlord_id': 'LID35937',
#   'opening_time': '6:15',
#   'closing_time': '19:45',
#   'open_days': ['Friday', 'Thursday', 'Saturday', 'Sunday', 'Monday'],
#   'city': 'Mannheim',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI58697',
#   'name': 'Property 710',
#   'address': 'Stuttgarter Straße 10, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.08,
#   'capacity': 8,
#   'available_space': 2,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID16555',
#   'opening_time': '7:45',
#   'closing_time': '9:00',
#   'open_days': ['Tuesday',
#    'Wednesday',
#    'Saturday',
#    'Friday',
#    'Sunday',
#    'Thursday',
#    'Monday'],
#   'city': 'Freiburg',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI10866',
#   'name': 'Property 344',
#   'address': 'Stuttgarter Straße 63, Heidelberg',
#   'latitude': 49.3984,
#   'longitude': 8.6724,
#   'price_per_hour': 1.59,
#   'capacity': 10,
#   'available_space': 2,
#   'special_access': 'storage room',
#   'landlord_id': 'LID77950',
#   'opening_time': '16:00',
#   'closing_time': '18:00',
#   'open_days': ['Thursday',
#    'Tuesday',
#    'Sunday',
#    'Friday',
#    'Wednesday',
#    'Saturday'],
#   'city': 'Heidelberg',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI31865',
#   'name': 'Property 415',
#   'address': 'Kantstraße 112, Karlsruhe',
#   'latitude': 49.0144,
#   'longitude': 8.4044,
#   'price_per_hour': 1.58,
#   'capacity': 6,
#   'available_space': 1,
#   'special_access': 'garage',
#   'landlord_id': 'LID15924',
#   'opening_time': '12:00',
#   'closing_time': '21:45',
#   'open_days': ['Sunday',
#    'Tuesday',
#    'Friday',
#    'Saturday',
#    'Thursday',
#    'Wednesday',
#    'Monday'],
#   'city': 'Karlsruhe',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI14167',
#   'name': 'Property 993',
#   'address': 'Goethestraße 53, Pforzheim',
#   'latitude': 48.8984,
#   'longitude': 8.701,
#   'price_per_hour': 1.06,
#   'capacity': 6,
#   'available_space': 2,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID75409',
#   'opening_time': '7:15',
#   'closing_time': '13:00',
#   'open_days': ['Friday', 'Saturday'],
#   'city': 'Pforzheim',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI35524',
#   'name': 'Property 363',
#   'address': 'Hegelstraße 5, Villingen-Schwenningen',
#   'latitude': 48.0732,
#   'longitude': 8.492,
#   'price_per_hour': 1.64,
#   'capacity': 6,
#   'available_space': 5,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID51560',
#   'opening_time': '17:00',
#   'closing_time': '19:00',
#   'open_days': ['Friday'],
#   'city': 'Villingen-Schwenningen',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI74734',
#   'name': 'Property 180',
#   'address': 'Bahnhofstraße 95, Stuttgart',
#   'latitude': 48.7758,
#   'longitude': 9.1829,
#   'price_per_hour': 1.84,
#   'capacity': 8,
#   'available_space': 1,
#   'special_access': 'garage',
#   'landlord_id': 'LID35312',
#   'opening_time': '21:45',
#   'closing_time': '22:00',
#   'open_days': ['Tuesday'],
#   'city': 'Stuttgart',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI10515',
#   'name': 'Property 188',
#   'address': 'Ludwigsburger Straße 36, Heidelberg',
#   'latitude': 49.3984,
#   'longitude': 8.6724,
#   'price_per_hour': 1.98,
#   'capacity': 7,
#   'available_space': 4,
#   'special_access': 'storage room',
#   'landlord_id': 'LID95233',
#   'opening_time': '8:45',
#   'closing_time': '11:30',
#   'open_days': ['Wednesday', 'Monday', 'Saturday'],
#   'city': 'Heidelberg',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI73520',
#   'name': 'Property 704',
#   'address': 'Friedrichstraße 65, Reutlingen',
#   'latitude': 48.4815,
#   'longitude': 9.2043,
#   'price_per_hour': 1.85,
#   'capacity': 7,
#   'available_space': 2,
#   'special_access': 'basement',
#   'landlord_id': 'LID31647',
#   'opening_time': '8:30',
#   'closing_time': '21:00',
#   'open_days': ['Sunday', 'Saturday', 'Tuesday'],
#   'city': 'Reutlingen',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI52513',
#   'name': 'Property 792',
#   'address': 'Kantstraße 65, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.89,
#   'capacity': 5,
#   'available_space': 1,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID79214',
#   'opening_time': '7:00',
#   'closing_time': '13:15',
#   'open_days': ['Sunday'],
#   'city': 'Freiburg',
# ...
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI99428',
#   'name': 'Property 706',
#   'address': 'Goethestraße 106, Esslingen',
#   'latitude': 48.74,
#   'longitude': 9.31,
#   'price_per_hour': 1.04,
#   'capacity': 8,
#   'available_space': 4,
#   'special_access': 'garage',
#   'landlord_id': 'LID33684',
#   'opening_time': '16:00',
#   'closing_time': '19:00',
#   'open_days': ['Sunday',
#    'Friday',
#    'Wednesday',
#    'Saturday',
#    'Monday',
#    'Tuesday'],
#   'city': 'Esslingen',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI17281',
#   'name': 'Property 612',
#   'address': 'Tübinger Straße 7, Karlsruhe',
#   'latitude': 49.0144,
#   'longitude': 8.4044,
#   'price_per_hour': 1.95,
#   'capacity': 9,
#   'available_space': 3,
#   'special_access': 'garage',
#   'landlord_id': 'LID28814',
#   'opening_time': '7:00',
#   'closing_time': '17:15',
#   'open_days': ['Saturday', 'Tuesday'],
#   'city': 'Karlsruhe',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI53115',
#   'name': 'Property 888',
#   'address': 'Mozartstraße 45, Konstanz',
#   'latitude': 47.666,
#   'longitude': 9.1732,
#   'price_per_hour': 1.05,
#   'capacity': 6,
#   'available_space': 5,
#   'special_access': 'garage',
#   'landlord_id': 'LID76243',
#   'opening_time': '20:45',
#   'closing_time': '22:45',
#   'open_days': ['Monday', 'Wednesday', 'Thursday'],
#   'city': 'Konstanz',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI44811',
#   'name': 'Property 349',
#   'address': 'Ludwigsburger Straße 99, Stuttgart',
#   'latitude': 48.7758,
#   'longitude': 9.1829,
#   'price_per_hour': 1.66,
#   'capacity': 10,
#   'available_space': 5,
#   'special_access': 'storage room',
#   'landlord_id': 'LID45402',
#   'opening_time': '14:00',
#   'closing_time': '16:30',
#   'open_days': ['Sunday',
#    'Tuesday',
#    'Thursday',
#    'Wednesday',
#    'Friday',
#    'Saturday'],
#   'city': 'Stuttgart',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI32281',
#   'name': 'Property 74',
#   'address': 'Kantstraße 18, Tübingen',
#   'latitude': 48.5204,
#   'longitude': 9.0568,
#   'price_per_hour': 1.47,
#   'capacity': 8,
#   'available_space': 5,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID12497',
#   'opening_time': '8:00',
#   'closing_time': '22:45',
#   'open_days': ['Monday', 'Wednesday', 'Friday'],
#   'city': 'Tübingen',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI86611',
#   'name': 'Property 262',
#   'address': 'Wilhelmstraße 134, Pforzheim',
#   'latitude': 48.8984,
#   'longitude': 8.701,
#   'price_per_hour': 1.46,
#   'capacity': 6,
#   'available_space': 4,
#   'special_access': 'basement',
#   'landlord_id': 'LID49388',
#   'opening_time': '7:45',
#   'closing_time': '14:45',
#   'open_days': ['Saturday', 'Friday', 'Tuesday', 'Thursday'],
#   'city': 'Pforzheim',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI42987',
#   'name': 'Property 37',
#   'address': 'Bodenseestraße 70, Karlsruhe',
#   'latitude': 49.0144,
#   'longitude': 8.4044,
#   'price_per_hour': 1.52,
#   'capacity': 10,
#   'available_space': 4,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID29569',
#   'opening_time': '10:00',
#   'closing_time': '18:00',
#   'open_days': ['Monday', 'Friday', 'Tuesday'],
#   'city': 'Karlsruhe',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI15326',
#   'name': 'Property 147',
#   'address': 'Kantstraße 61, Ludwigsburg',
#   'latitude': 48.8982,
#   'longitude': 9.1941,
#   'price_per_hour': 1.59,
#   'capacity': 8,
#   'available_space': 3,
#   'special_access': 'storage room',
#   'landlord_id': 'LID71737',
#   'opening_time': '8:30',
#   'closing_time': '15:15',
#   'open_days': ['Sunday',
#    'Thursday',
#    'Saturday',
#    'Wednesday',
#    'Tuesday',
#    'Monday',
#    'Friday'],
#   'city': 'Ludwigsburg',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI23436',
#   'name': 'Property 287',
#   'address': 'Bahnhofstraße 136, Konstanz',
#   'latitude': 47.666,
#   'longitude': 9.1732,
#   'price_per_hour': 1.72,
#   'capacity': 5,
#   'available_space': 1,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID52620',
#   'opening_time': '20:00',
#   'closing_time': '22:30',
#   'open_days': ['Monday',
#    'Wednesday',
#    'Saturday',
#    'Friday',
#    'Sunday',
#    'Thursday',
#    'Tuesday'],
#   'city': 'Konstanz',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI57839',
#   'name': 'Property 364',
#   'address': 'Goethestraße 125, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.07,
#   'capacity': 7,
#   'available_space': 5,
#   'special_access': 'garage',
#   'landlord_id': 'LID22306',
#   'opening_time': '16:30',
#   'closing_time': '21:00',
#   'open_days': ['Monday', 'Tuesday', 'Thursday'],
#   'city': 'Freiburg',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI71551',
#   'name': 'Property 303',
#   'address': 'Stuttgarter Straße 103, Ludwigsburg',
#   'latitude': 48.8982,
#   'longitude': 9.1941,
#   'price_per_hour': 1.56,
#   'capacity': 7,
#   'available_space': 2,
#   'special_access': 'storage room',
#   'landlord_id': 'LID98006',
#   'opening_time': '14:30',
#   'closing_time': '17:15',
#   'open_days': ['Tuesday'],
#   'city': 'Ludwigsburg',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI74467',
#   'name': 'Property 617',
#   'address': 'Ludwigsburger Straße 119, Villingen-Schwenningen',
#   'latitude': 48.0732,
#   'longitude': 8.492,
#   'price_per_hour': 1.27,
#   'capacity': 7,
#   'available_space': 2,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID46557',
#   'opening_time': '17:00',
#   'closing_time': '20:00',
#   'open_days': ['Sunday', 'Saturday'],
#   'city': 'Villingen-Schwenningen',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI78452',
#   'name': 'Property 365',
#   'address': 'Heidelberger Straße 82, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.6,
#   'capacity': 10,
#   'available_space': 1,
#   'special_access': 'storage room',
#   'landlord_id': 'LID61104',
#   'opening_time': '13:00',
#   'closing_time': '22:45',
#   'open_days': ['Thursday'],
#   'city': 'Freiburg',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI39129',
#   'name': 'Property 514',
#   'address': 'Hauptstraße 78, Ulm',
#   'latitude': 48.4011,
#   'longitude': 9.9876,
#   'price_per_hour': 1.72,
#   'capacity': 6,
#   'available_space': 4,
#   'special_access': 'garage',
#   'landlord_id': 'LID33789',
#   'opening_time': '18:00',
#   'closing_time': '22:00',
#   'open_days': ['Monday', 'Thursday', 'Tuesday', 'Sunday', 'Friday'],
#   'city': 'Ulm',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI55575',
#   'name': 'Property 53',
#   'address': 'Hegelstraße 107, Stuttgart',
#   'latitude': 48.7758,
#   'longitude': 9.1829,
#   'price_per_hour': 1.34,
#   'capacity': 8,
#   'available_space': 3,
#   'special_access': 'storage room',
#   'landlord_id': 'LID45825',
#   'opening_time': '8:45',
#   'closing_time': '17:15',
#   'open_days': ['Saturday', 'Tuesday', 'Monday', 'Thursday', 'Friday'],
#   'city': 'Stuttgart',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI80870',
#   'name': 'Property 768',
#   'address': 'Goethestraße 123, Tübingen',
#   'latitude': 48.5204,
#   'longitude': 9.0568,
#   'price_per_hour': 1.11,
#   'capacity': 8,
#   'available_space': 2,
#   'special_access': 'basement',
#   'landlord_id': 'LID25224',
#   'opening_time': '14:45',
#   'closing_time': '18:45',
#   'open_days': ['Thursday',
#    'Monday',
#    'Friday',
#    'Tuesday',
#    'Saturday',
#    'Wednesday'],
#   'city': 'Tübingen',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI38993',
#   'name': 'Property 175',
#   'address': 'Schlossstraße 125, Konstanz',
#   'latitude': 47.666,
#   'longitude': 9.1732,
#   'price_per_hour': 1.42,
#   'capacity': 10,
#   'available_space': 1,
#   'special_access': 'garage',
#   'landlord_id': 'LID79574',
#   'opening_time': '10:45',
#   'closing_time': '21:00',
#   'open_days': ['Tuesday', 'Sunday', 'Saturday', 'Friday'],
#   'city': 'Konstanz',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI23070',
#   'name': 'Property 526',
#   'address': 'Kantstraße 13, Villingen-Schwenningen',
#   'latitude': 48.0732,
#   'longitude': 8.492,
#   'price_per_hour': 1.77,
#   'capacity': 7,
#   'available_space': 4,
#   'special_access': 'storage room',
#   'landlord_id': 'LID65388',
#   'opening_time': '16:15',
#   'closing_time': '20:00',
#   'open_days': ['Monday'],
#   'city': 'Villingen-Schwenningen',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Key can be picked up at the local office'},
#  {'private_id': 'PRI44018',
#   'name': 'Property 45',
#   'address': 'Tübinger Straße 84, Konstanz',
#   'latitude': 47.666,
#   'longitude': 9.1732,
#   'price_per_hour': 1.32,
#   'capacity': 8,
#   'available_space': 4,
#   'special_access': 'basement',
#   'landlord_id': 'LID54117',
#   'opening_time': '6:15',
#   'closing_time': '22:00',
#   'open_days': ['Sunday', 'Tuesday', 'Wednesday', 'Friday', 'Monday'],
#   'city': 'Konstanz',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI60035',
#   'name': 'Property 996',
#   'address': 'Kantstraße 146, Heidelberg',
#   'latitude': 49.3984,
#   'longitude': 8.6724,
#   'price_per_hour': 1.21,
#   'capacity': 10,
#   'available_space': 3,
#   'special_access': 'storage room',
#   'landlord_id': 'LID34476',
#   'opening_time': '6:45',
#   'closing_time': '11:30',
#   'open_days': ['Sunday', 'Saturday', 'Friday'],
#   'city': 'Heidelberg',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Key available at the front desk'},
#  {'private_id': 'PRI90832',
#   'name': 'Property 840',
#   'address': 'Tübinger Straße 131, Pforzheim',
#   'latitude': 48.8984,
#   'longitude': 8.701,
#   'price_per_hour': 1.19,
#   'capacity': 5,
#   'available_space': 1,
#   'special_access': 'basement',
#   'landlord_id': 'LID78842',
#   'opening_time': '16:45',
#   'closing_time': '22:45',
#   'open_days': ['Wednesday',
#    'Sunday',
#    'Friday',
#    'Saturday',
#    'Tuesday',
#    'Thursday'],
#   'city': 'Pforzheim',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI58040',
#   'name': 'Property 426',
#   'address': 'Heidelberger Straße 128, Ulm',
#   'latitude': 48.4011,
#   'longitude': 9.9876,
#   'price_per_hour': 1.48,
#   'capacity': 10,
#   'available_space': 3,
#   'special_access': 'garage',
#   'landlord_id': 'LID57759',
#   'opening_time': '13:15',
#   'closing_time': '22:00',
#   'open_days': ['Friday'],
#   'city': 'Ulm',
#   'note_area': 'Parking space may be tight due to ongoing construction.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI37726',
#   'name': 'Property 482',
#   'address': 'Friedrichstraße 35, Baden-Baden',
#   'latitude': 48.7591,
#   'longitude': 8.24,
#   'price_per_hour': 1.7,
#   'capacity': 10,
#   'available_space': 3,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID96236',
#   'opening_time': '11:45',
#   'closing_time': '14:30',
#   'open_days': ['Tuesday', 'Sunday', 'Thursday', 'Monday'],
#   'city': 'Baden-Baden',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Please contact the landlord for access instructions'},
#  {'private_id': 'PRI46578',
#   'name': 'Property 5',
#   'address': 'Hegelstraße 124, Konstanz',
#   'latitude': 47.666,
#   'longitude': 9.1732,
#   'price_per_hour': 1.92,
#   'capacity': 6,
#   'available_space': 2,
#   'special_access': 'storage room',
#   'landlord_id': 'LID46069',
#   'opening_time': '20:30',
#   'closing_time': '22:45',
#   'open_days': ['Sunday', 'Tuesday', 'Thursday'],
#   'city': 'Konstanz',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI81286',
#   'name': 'Property 679',
#   'address': 'Bodenseestraße 51, Esslingen',
#   'latitude': 48.74,
#   'longitude': 9.31,
#   'price_per_hour': 1.59,
#   'capacity': 9,
#   'available_space': 5,
#   'special_access': 'garage',
#   'landlord_id': 'LID78904',
#   'opening_time': '15:15',
#   'closing_time': '19:30',
#   'open_days': ['Tuesday',
#    'Thursday',
#    'Sunday',
#    'Monday',
#    'Wednesday',
#    'Saturday',
#    'Friday'],
#   'city': 'Esslingen',
#   'note_area': 'Access may be limited during the night due to maintenance work.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI29022',
#   'name': 'Property 867',
#   'address': 'Heidelberger Straße 74, Freiburg',
#   'latitude': 47.999,
#   'longitude': 7.8425,
#   'price_per_hour': 1.69,
#   'capacity': 9,
#   'available_space': 2,
#   'special_access': 'rooftop',
#   'landlord_id': 'LID30370',
#   'opening_time': '9:00',
#   'closing_time': '22:00',
#   'open_days': ['Thursday',
#    'Tuesday',
#    'Saturday',
#    'Friday',
#    'Sunday',
#    'Monday'],
#   'city': 'Freiburg',
#   'note_area': 'The space is well-lit but may be dusty in dry weather.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI95726',
#   'name': 'Property 536',
#   'address': 'Goethestraße 127, Heidelberg',
#   'latitude': 49.3984,
#   'longitude': 8.6724,
#   'price_per_hour': 1.77,
#   'capacity': 6,
#   'available_space': 2,
#   'special_access': 'basement',
#   'landlord_id': 'LID31147',
#   'opening_time': '9:45',
#   'closing_time': '14:15',
#   'open_days': ['Saturday', 'Monday'],
#   'city': 'Heidelberg',
#   'note_area': 'Lot is cleaned every Monday morning.',
#   'key_access_info': 'Access via key box with code (code: 1234)'},
#  {'private_id': 'PRI32821',
#   'name': 'Property 575',
#   'address': 'Wilhelmstraße 114, Reutlingen',
#   'latitude': 48.4815,
#   'longitude': 9.2043,
#   'price_per_hour': 1.43,
#   'capacity': 10,
#   'available_space': 5,
#   'special_access': 'basement',
#   'landlord_id': 'LID40008',
#   'opening_time': '19:15',
#   'closing_time': '20:15',
#   'open_days': ['Sunday', 'Friday', 'Thursday'],
#   'city': 'Reutlingen',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Access via smart lock with app'},
#  {'private_id': 'PRI90848',
#   'name': 'Property 564',
#   'address': 'Schlossstraße 26, Tübingen',
#   'latitude': 48.5204,
#   'longitude': 9.0568,
#   'price_per_hour': 1.77,
#   'capacity': 9,
#   'available_space': 5,
#   'special_access': 'garage',
#   'landlord_id': 'LID15423',
#   'opening_time': '18:45',
#   'closing_time': '21:45',
#   'open_days': ['Sunday',
#    'Tuesday',
#    'Saturday',
#    'Monday',
#    'Thursday',
#    'Friday',
#    'Wednesday'],
#   'city': 'Tübingen',
#   'note_area': 'Parking lot in good condition, recently paved.',
#   'key_access_info': 'Access via smart lock with app'},
#  ...]

# %%
# Output the data in JSON format
json_data = json.dumps(data, indent=4)
json_data[:500]

# Save the generated data to a JSON file
with open('private_parking.json', 'w') as json_file:
    json.dump(data, json_file, indent=4)
